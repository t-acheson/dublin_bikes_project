# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import pickle
import numpy as np

# %%
#merging data files from workbench 

# data0 = pd.read_csv('testData.csv')
# data1 = pd.read_csv('testData1.csv')
# data2 = pd.read_csv('testData2.csv')
# data3 = pd.read_csv('testData3.csv')
# data4 = pd.read_csv('testData4.csv')
# data5 = pd.read_csv('testData5.csv')
# data6 = pd.read_csv('testData6.csv')
# data7 = pd.read_csv('testData7.csv')
# data8 = pd.read_csv('testData8.csv')
# data9 = pd.read_csv('testData9.csv')
# data10 = pd.read_csv('testData10.csv')
# data11 = pd.read_csv('testData11.csv')
# data12 = pd.read_csv('testData12.csv')
# data13 = pd.read_csv('testData13.csv')
# data14 = pd.read_csv('testData14.csv')

# merged_data = pd.concat([data0, data1, data2, data3, data4, data5,data6,data7,data8,data9,data10,data11,data12, data13, data14], ignore_index=True)
# merged_data.to_csv('modelData.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data0 = pd.read_csv('testData.csv')
#       2 data1 = pd.read_csv('testData1.csv')
#       3 data2 = pd.read_csv('testData2.csv')
#
# File c:\Users\taraa\anaconda3\envs\comp30830\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\taraa\anaconda3\envs\comp30830\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\taraa\anaconda3\envs\comp30830\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\taraa\anaconda3\envs\comp30830\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\taraa\anaconda3\envs\comp30830\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'testData.csv'

# %%
df = pd.read_csv('modelData.csv')

# %%
df.head()
# Out:
#    update_no  number   last_update  available_bike_stands status  \
# 0          1      42  1.709200e+12                     28   OPEN
# 1          2      30  1.709200e+12                     11   OPEN
# 2          3      54  1.709200e+12                     17   OPEN
# 3          4     108  1.709200e+12                     35   OPEN
# 4          5      20  1.709200e+12                      0   OPEN
#
#    available_bikes
# 0                2
# 1                9
# 2               16
# 3                0
# 4               30

# %%
df['last_update'] = pd.to_datetime(df['last_update'], unit='ms', errors='ignore')
#splitting update into date/hour
df['date'] = df['last_update'].dt.date
df['hours'] = df['last_update'].dt.hour

date_str = df['date'].astype(str)
hour_str = df['hours'].astype(str)

df['date'] = date_str + ' ' + hour_str + ':00'


df = df.drop(columns=['last_update'])
df = df.drop(columns=['hours'])
df = df.drop(columns=['status'])


# df = df.drop(columns=['status'])
# Out:
# C:\Users\taraa\AppData\Local\Temp\ipykernel_4300\1503980813.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df['last_update'] = pd.to_datetime(df['last_update'], unit='ms', errors='ignore')

# %%
df.head()
# Out:
#    update_no  number  available_bike_stands  available_bikes             date
# 0          1      42                     28                2  2024-02-29 9:00
# 1          2      30                     11                9  2024-02-29 9:00
# 2          3      54                     17               16  2024-02-29 9:00
# 3          4     108                     35                0  2024-02-29 9:00
# 4          5      20                      0               30  2024-02-29 9:00

# %%
#get weather file and split update into date/hour/min
weather_df = pd.read_csv('weatherData.csv')

weather_df.head()
# Out:
#      name  temp_c weather_condition  wind_mph wind_dir  precip_mm   ID  \
# 0  Dublin       7     Partly cloudy        14       SW          0    1
# 1  Dublin       8     Partly cloudy        14       SW          0  323
# 2  Dublin       7     Partly cloudy        15       SE          0  439
# 3  Dublin       8     Partly cloudy        15       SE          0  441
# 4  Dublin       8     Partly cloudy        15      ESE          0  443
#
#         last_update              date     hours
# 0  27/02/2024 09:30  27/02/2024 00:00   9:00 am
# 1  27/02/2024 10:30  27/02/2024 00:00  10:00 am
# 2  07/03/2024 09:30  07/03/2024 00:00   9:00 am
# 3  07/03/2024 11:15  07/03/2024 00:00  11:00 am
# 4  07/03/2024 15:15  07/03/2024 00:00   3:00 pm

# %%
#getting weather datetime to format correctly for merge 
weather_df['date'] = pd.to_datetime(weather_df['date'])
weather_df['hours'] = pd.to_datetime(weather_df['hours'])

weather_df['hours'] = weather_df['hours'].dt.hour

weather_df.head()
# Out:
# C:\Users\taraa\AppData\Local\Temp\ipykernel_4300\309059847.py:2: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   weather_df['date'] = pd.to_datetime(weather_df['date'])
# C:\Users\taraa\AppData\Local\Temp\ipykernel_4300\309059847.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   weather_df['hours'] = pd.to_datetime(weather_df['hours'])
#      name  temp_c weather_condition  wind_mph wind_dir  precip_mm   ID  \
# 0  Dublin       7     Partly cloudy        14       SW          0    1
# 1  Dublin       8     Partly cloudy        14       SW          0  323
# 2  Dublin       7     Partly cloudy        15       SE          0  439
# 3  Dublin       8     Partly cloudy        15       SE          0  441
# 4  Dublin       8     Partly cloudy        15      ESE          0  443
#
#         last_update       date  hours
# 0  27/02/2024 09:30 2024-02-27      9
# 1  27/02/2024 10:30 2024-02-27     10
# 2  07/03/2024 09:30 2024-03-07      9
# 3  07/03/2024 11:15 2024-03-07     11
# 4  07/03/2024 15:15 2024-03-07     15

# %%
date_str = weather_df['date'].astype(str)
hour_str = weather_df['hours'].astype(str)

weather_df['date'] = date_str + ' ' + hour_str + ':00'

weather_df.head()
# Out:
#      name  temp_c weather_condition  wind_mph wind_dir  precip_mm   ID  \
# 0  Dublin       7     Partly cloudy        14       SW          0    1
# 1  Dublin       8     Partly cloudy        14       SW          0  323
# 2  Dublin       7     Partly cloudy        15       SE          0  439
# 3  Dublin       8     Partly cloudy        15       SE          0  441
# 4  Dublin       8     Partly cloudy        15      ESE          0  443
#
#         last_update              date  hours
# 0  27/02/2024 09:30   2024-02-27 9:00      9
# 1  27/02/2024 10:30  2024-02-27 10:00     10
# 2  07/03/2024 09:30   2024-03-07 9:00      9
# 3  07/03/2024 11:15  2024-03-07 11:00     11
# 4  07/03/2024 15:15  2024-03-07 15:00     15

# %%
#merge weather & bike files on date & hour 
# weather_df = weather_df.drop(columns=['ID'])
# weather_df = weather_df.drop(columns=['name'])
# weather_df = weather_df.drop(columns=['last_update'])

merged_df = pd.merge(df, weather_df, on=['date'])

# %%
# merged_df.head()
merged_df.tail()
# Out:
#          update_no  number  available_bike_stands  available_bikes  \
# 1481350     749776      92                     10               29
# 1481351     749777      21                      1               29
# 1481352     749777      21                      1               29
# 1481353     749778      88                     11               19
# 1481354     749778      88                     11               19
#
#                     date  temp_c weather_condition  wind_mph wind_dir  \
# 1481350  2024-03-30 9:00      10     Partly cloudy        11        S
# 1481351  2024-03-30 9:00      10     Partly cloudy        13        S
# 1481352  2024-03-30 9:00      10     Partly cloudy        11        S
# 1481353  2024-03-30 9:00      10     Partly cloudy        13        S
# 1481354  2024-03-30 9:00      10     Partly cloudy        11        S
#
#          precip_mm  hours
# 1481350          0      9
# 1481351          0      9
# 1481352          0      9
# 1481353          0      9
# 1481354          0      9

# %%
#TODO split data based on y = available_bikes and x = temp, wind_mph, precip_mn 

# #split data  & use "available_bikes" as target 
# X = df.iloc[:, :-1] # Features (all columns except the last one)
# y = df.iloc[:, -1]   # Target (the last column - available_bikes)

# X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Assuming X_train and Y_train are already defined
# Ensure Y_train is a 1D array
Y_train = np.ravel(Y_train)

# Ensure X_train is a 2D array
if len(X_train.shape) == 1:
    X_train = X_train.reshape(-1, 1)

# Create and train the linear regression model
model = LinearRegression()
model.fit(X_train, Y_train)

# Save the model to a file
filename = 'linear_regression_model.sav'
import pickle
pickle.dump(model, open(filename, 'wb'))

# Load the model from the file
loaded_model = pickle.load(open(filename, 'rb'))

# Use the loaded model to make predictions
predictions = loaded_model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4300\702085434.py in ?()
#       7     X_train = X_train.reshape(-1, 1)
#       8
#       9 # Create and train the linear regression model
#      10 model = LinearRegression()
# ---> 11 model.fit(X_train, Y_train)
#      12
#      13 # Save the model to a file
#      14 filename = 'linear_regression_model.sav'
#
# c:\Users\taraa\anaconda3\envs\comp30830\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1470                 skip_parameter_validation=(
#    1471                     prefer_skip_nested_validation or global_skip_validation
#    1472                 )
#    1473             ):
# -> 1474                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\taraa\anaconda3\envs\comp30830\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X, y, sample_weight)
#     574         n_jobs_ = self.n_jobs
#     575
#     576         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     577
# --> 578         X, y = self._validate_data(
#     579             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     580         )
#     581
#
# c:\Users\taraa\anaconda3\envs\comp30830\Lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     646                 if "estimator" not in check_y_params:
#     647                     check_y_params = {**default_check_params, **check_y_params}
#     648                 y = check_array(y, input_name="y", **check_y_params)
#     649             else:
# --> 650                 X, y = check_X_y(X, y, **check_params)
#     651             out = X, y
#     652
#     653         if not no_val_X and check_params.get("ensure_2d", True):
#
# c:\Users\taraa\anaconda3\envs\comp30830\Lib\site-packages\sklearn\utils\validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1259         raise ValueError(
#    1260             f"{estimator_name} requires y to be passed, but the target y is None"
#    1261         )
#    1262
# -> 1263     X = check_array(
#    1264         X,
#    1265         accept_sparse=accept_sparse,
#    1266         accept_large_sparse=accept_large_sparse,
#
# c:\Users\taraa\anaconda3\envs\comp30830\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     994                         )
#     995                     array = xp.astype(array, dtype, copy=False)
#     996                 else:
#     997                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# --> 998             except ComplexWarning as complex_warning:
#     999                 raise ValueError(
#    1000                     "Complex data not supported\n{}\n".format(array)
#    1001                 ) from complex_warning
#
# c:\Users\taraa\anaconda3\envs\comp30830\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp)
#     517         # Use NumPy API to support order
#     518         if copy is True:
#     519             array = numpy.array(array, order=order, dtype=dtype)
#     520         else:
# --> 521             array = numpy.asarray(array, order=order, dtype=dtype)
#     522
#     523         # At this point array is a NumPy ndarray. We convert it to an array
#     524         # container that is consistent with the input's namespace.
#
# c:\Users\taraa\anaconda3\envs\comp30830\Lib\site-packages\pandas\core\generic.py in ?(self, dtype)
#    2148     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    2149         values = self._values
# -> 2150         arr = np.asarray(values, dtype=dtype)
#    2151         if (
#    2152             astype_is_view(values.dtype, arr.dtype)
#    2153             and using_copy_on_write()
#
# TypeError: float() argument must be a string or a real number, not 'datetime.date'

# %% [markdown]
# sort by last_update in ascending order - train on older data, train on new
# drop minutes on last update - keep hour to work out hourly
# can't use timestamp on regression, use sktime for timeseries, use sklearn as it gives metrics to get percentage error :)
# use available_bike as y/dependable and minus from available_bike_stands at the end

# %% [markdown]
# split timestamp into hour/min
# combine weather on the hour
#
# covariance matrix - most effective attributes
#     build model based on ^
#
# 70-80% accuraccy needed
#
#
# DO BOTH BIKE STANDS AND AVAILABLE BIKE STSANDS MODEL - same model diff input, do both
