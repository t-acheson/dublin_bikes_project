# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import pickle
import numpy as np

# %%
df = pd.read_csv('finalModelData.csv')

# %%
stationID = df['number'].unique()
df = df.drop_duplicates()


df.head()
# Out:
#    update_no  number  available_bike_stands  available_bikes  \
# 0        457      42                     18               12
# 1        458      30                     16                4
# 2        459      54                     16               17
# 3        460     108                     19               16
# 4        461      20                      0               30
#
#                date  temp_c weather_condition  wind_mph wind_dir  precip_mm  \
# 0  2024-03-07 11:00       8     Partly cloudy        15       SE          0
# 1  2024-03-07 11:00       8     Partly cloudy        15       SE          0
# 2  2024-03-07 11:00       8     Partly cloudy        15       SE          0
# 3  2024-03-07 11:00       8     Partly cloudy        15       SE          0
# 4  2024-03-07 11:00       8     Partly cloudy        15       SE          0
#
#    hours
# 0     11
# 1     11
# 2     11
# 3     11
# 4     11

# %%
for station in stationID:
    df_station = df[df['number'] == station]

    #split data 
    X = df_station[['temp_c', 'wind_mph', 'precip_mm', 'hours']]
    Y = df_station['available_bikes']

    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=0)

    #model 
    model = LinearRegression()
    model.fit(X_train, Y_train)
    
    #save
    filename = f'model_{station}.pkl'
    with open(filename, 'wb') as file:
        pickle.dump(model, file)
    print(f"Model for station {station} saved to {filename}")


    #
# Out:
# Model for station 42 saved to model_42.pkl
# Model for station 30 saved to model_30.pkl
# Model for station 54 saved to model_54.pkl
# Model for station 108 saved to model_108.pkl
# Model for station 20 saved to model_20.pkl
# Model for station 56 saved to model_56.pkl
# Model for station 6 saved to model_6.pkl
# Model for station 18 saved to model_18.pkl
# Model for station 32 saved to model_32.pkl
# Model for station 52 saved to model_52.pkl
# Model for station 48 saved to model_48.pkl
# Model for station 13 saved to model_13.pkl
# Model for station 43 saved to model_43.pkl
# Model for station 31 saved to model_31.pkl
# Model for station 98 saved to model_98.pkl
# Model for station 14 saved to model_14.pkl
# Model for station 1 saved to model_1.pkl
# Model for station 23 saved to model_23.pkl
# Model for station 106 saved to model_106.pkl
# Model for station 112 saved to model_112.pkl
# Model for station 68 saved to model_68.pkl
# Model for station 74 saved to model_74.pkl
# Model for station 87 saved to model_87.pkl
# Model for station 84 saved to model_84.pkl
# Model for station 90 saved to model_90.pkl
# Model for station 11 saved to model_11.pkl
# Model for station 17 saved to model_17.pkl
# Model for station 45 saved to model_45.pkl
# Model for station 114 saved to model_114.pkl
# Model for station 72 saved to model_72.pkl
# Model for station 63 saved to model_63.pkl
# Model for station 113 saved to model_113.pkl
# Model for station 91 saved to model_91.pkl
# Model for station 99 saved to model_99.pkl
# Model for station 9 saved to model_9.pkl
# Model for station 67 saved to model_67.pkl
# Model for station 116 saved to model_116.pkl
# Model for station 55 saved to model_55.pkl
# Model for station 62 saved to model_62.pkl
# Model for station 5 saved to model_5.pkl
# Model for station 97 saved to model_97.pkl
# Model for station 61 saved to model_61.pkl
# Model for station 77 saved to model_77.pkl
# Model for station 73 saved to model_73.pkl
# Model for station 4 saved to model_4.pkl
# Model for station 49 saved to model_49.pkl
# Model for station 19 saved to model_19.pkl
# Model for station 7 saved to model_7.pkl
# Model for station 60 saved to model_60.pkl
# Model for station 102 saved to model_102.pkl
# Model for station 38 saved to model_38.pkl
# Model for station 53 saved to model_53.pkl
# Model for station 58 saved to model_58.pkl
# Model for station 66 saved to model_66.pkl
# Model for station 104 saved to model_104.pkl
# Model for station 101 saved to model_101.pkl
# Model for station 115 saved to model_115.pkl
# Model for station 47 saved to model_47.pkl
# Model for station 117 saved to model_117.pkl
# Model for station 8 saved to model_8.pkl
# Model for station 27 saved to model_27.pkl
# Model for station 16 saved to model_16.pkl
# Model for station 96 saved to model_96.pkl
# Model for station 82 saved to model_82.pkl
# Model for station 76 saved to model_76.pkl
# Model for station 71 saved to model_71.pkl
# Model for station 79 saved to model_79.pkl
# Model for station 69 saved to model_69.pkl
# Model for station 25 saved to model_25.pkl
# Model for station 51 saved to model_51.pkl
# Model for station 37 saved to model_37.pkl
# Model for station 59 saved to model_59.pkl
# Model for station 95 saved to model_95.pkl
# Model for station 94 saved to model_94.pkl
# Model for station 105 saved to model_105.pkl
# Model for station 36 saved to model_36.pkl
# Model for station 93 saved to model_93.pkl
# Model for station 22 saved to model_22.pkl
# Model for station 50 saved to model_50.pkl
# Model for station 110 saved to model_110.pkl
# Model for station 12 saved to model_12.pkl
# Model for station 34 saved to model_34.pkl
# Model for station 78 saved to model_78.pkl
# Model for station 2 saved to model_2.pkl
# Model for station 75 saved to model_75.pkl
# Model for station 111 saved to model_111.pkl
# Model for station 26 saved to model_26.pkl
# Model for station 65 saved to model_65.pkl
# Model for station 15 saved to model_15.pkl
# Model for station 86 saved to model_86.pkl
# Model for station 35 saved to model_35.pkl
# Model for station 10 saved to model_10.pkl
# Model for station 100 saved to model_100.pkl
# Model for station 24 saved to model_24.pkl
# Model for station 64 saved to model_64.pkl
# Model for station 109 saved to model_109.pkl
# Model for station 85 saved to model_85.pkl
# Model for station 107 saved to model_107.pkl
# Model for station 33 saved to model_33.pkl
# Model for station 44 saved to model_44.pkl
# Model for station 89 saved to model_89.pkl
# Model for station 57 saved to model_57.pkl
# Model for station 80 saved to model_80.pkl
# Model for station 41 saved to model_41.pkl
# Model for station 3 saved to model_3.pkl
# Model for station 40 saved to model_40.pkl
# Model for station 29 saved to model_29.pkl
# Model for station 103 saved to model_103.pkl
# Model for station 28 saved to model_28.pkl
# Model for station 39 saved to model_39.pkl
# Model for station 83 saved to model_83.pkl
# Model for station 92 saved to model_92.pkl
# Model for station 21 saved to model_21.pkl
# Model for station 88 saved to model_88.pkl
